# %%
import pandas as pd

path = "2025 ASA DataFest-update2-2025-03-19/"
df_leases = pd.read_csv(path + "Leases.csv")

df_leases.loc[df_leases.market == "Los Angeles"]
# Out:
#         year quarter  monthsigned       market             building_name  \
# 1160    2018      Q1          1.0  Los Angeles      100 Corporate Pointe
# 1161    2018      Q1          1.0  Los Angeles            11601 Wilshire
# 1162    2018      Q1          1.0  Los Angeles            11601 Wilshire
# 1163    2018      Q1          1.0  Los Angeles               1358 5th St
# 1164    2018      Q1          1.0  Los Angeles  1999 Avenue of the Stars
# ...      ...     ...          ...          ...                       ...
# 194520  2024      Q4         12.0  Los Angeles            Skyview Center
# 194521  2024      Q4         12.0  Los Angeles       Ten100 Santa Monica
# 194522  2024      Q4         12.0  Los Angeles                  The Bloc
# 194523  2024      Q4         12.0  Los Angeles                   Tower 1
# 194524  2024      Q4         12.0  Los Angeles                       NaN
#
#                                               building_id  \
# ...
